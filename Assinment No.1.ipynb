# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
# Write your code here
name = "Syed Muhammad Abdullah"
print(name.upper())
# Out:
# SYED MUHAMMAD ABDULLAH

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
# Write your code here
fruit = input("Enter your fav fruit:  ")
print(len(fruit))
# Out:
# Enter your fav fruit:   Apple
# 5

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
# Write your code here
sentence = "Python is fun"
new_sentence = sentence.replace("fun","awesome")
print(new_sentence)
# Out:
# Python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
# Write your code here
string = "Hello World"
print(string.index("World"))
# Out:
# 6

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
# Write your code here
email = input("Enter your Email Adress:  ")
email_lower = email.lower()
print(email_lower)
# Out:
# Enter your Email Adress:   FLDKS@gmail.com
# fldks@gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
# Write your code here
course = " Python Programming "
course_no_extra_space = course.strip()
print(course_no_extra_space)
# Out:
# Python Programming

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
# Write your code here
paragraph = "Welcome to coding"
print(paragraph.count("o"))
# Out:
# 3

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
# Write your code here
age = int(input("Enter your age:  "))
print(age)
# Out:
# Enter your age:   23
# 23

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
# Write your code here
num = int(float("15.99"))
print(num)
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
# Write your code here
num1 = int(input("Enter your num1:  "))
num2 = int(input("Enter your num2:  "))
print(num1+num2)
# Out:
# Enter your num1:   2
# Enter your num2:   2
# 4

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
# Write your code here
count = str(100)
isinstance(count,str)
# Out:
# True

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
# Write your code here
price = float(input("Enter price:  "))
price_int = int(price)
print(price_int)
# Out:
# Enter price:   45.6
# 45

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
# Write your code here
value1 = "10"
value2 = "20"
print(int(value1) + int(value2))
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
# Write your code here
number = "50.5"
print(float(number) + 10)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
# Write your code here
name = input("Enter your name:  ")
city = input("Enter your city:  ")
print(f"Hello {name}, welcome to {city}.")
# Out:
# Enter your name:   Abdullah
# Enter your city:   Karachi
# Hello Abdullah, welcome to Karachi.

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
# Write your code here
num1 = int(input("Enter your num1:  "))
num2 = int(input("Enter your num2:  "))
print(num1*num2)
# Out:
# Enter your num1:   2
# Enter your num2:   4
# 8

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
# Write your code here
color = input("Enter your favorite color:  ")
print(f"I also like {color}.")
# Out:
# Enter your favorite color:   blue
# I also like blue.

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
# Write your code here
birth_year = int(input("Enter your birth year:  "))
age = 2026 - birth_year
print(age)
# Out:
# Enter your birth year:   2009
# 17

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
# Write your code here
word = input("Type any word:  ")
print(word*5)
# Out:
# Type any word:   hello
# hellohellohellohellohello

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
# Write your code here
mobile = input("Enter your Mobile number:  ")
print("You entered:", mobile)
# Out:
# Enter your Mobile number:   03312293944
# You entered: 03312293944

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
# Write your code here
a = 10
b = 3
print(a % b)
# Out:
# 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
# Write your code here
print(15>10 and 15<20)
# Out:
# True

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
# Write your code here
number = int(input("Enter any number:  "))
print(number>100)
# Out:
# Enter any number:   999
# True

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
# Write your code here
power = 2**5
print(power)
# Out:
# 32

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
# Write your code here
print(50 == 100)
# Out:
# False

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
# Write your code here
a = True
b = False
result = a or b
print(result)
# Out:
# True

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
# Write your code here
number = int(input("Enter the number:  "))
if number>0:
    print("Number is psitive")
elif number<0:
    print("Number is negative")
else:
    print("Number is zero")
# Out:
# Enter the number:   -54
# Number is negative

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
# Write your code here
age = int(input("Enter your age:  "))
if age>=18:
    print("Eligible for Vote")
# Out:
# Enter your age:   19
# Eligible for Vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
# Write your code here
number = int(input("Enter the number:  "))
if number % 2 == 0:
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Enter the number:   4
# Number is Even

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
# Write your code here
num1 = int(input("Enter your num1:  "))
num2 = int(input("Enter your num2:  "))
if num1>num2:
    print("First number is greater")
elif num2>num1:
    print("Secont number is greater")
else:
    print("Both numbers are equal")
# Out:
# Enter your num1:   34
# Enter your num2:   54
# Secont number is greater

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
# Write your code here
marks = int(input("Enter your marks:  "))
if marks >= 33:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your marks:   59
# Pass

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
# Write your code here
text = input("Enter anything:  ")
if text:
    print("Input is empty")
else:
    print("Input is full")
# Out:
# Enter anything:
# Input is empty

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
# Write your code here
password = input("Enter your password:  ")
if password == "python123":
    print("Access Granted")
else:
    print("Wrong Password")
# Out:
# Enter your password:   python123
# Access Granted

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
# Write your code here
number = int(input("Enter the number:  "))
if number == 0:
    print("Yes the input number is zero")
else:
    print("Yes the input number is zero")
# Out:
# Enter the number:   0
# Yes the input number is zero

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
# Write your code here
persentage = float(input("Enter your persentage:  "))
if persentage>=90:
    grade = "A"
elif persentage>= 80:
    grade = "B"
elif persentage>= 70:
    grade = "C"
else:
    grade = "D"
print(f"Grade: {grade}")
# Out:
# Enter your persentage:   60
# Grade: D

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
# Write your code here
temperature = float(input("Enter your temperature:  "))
if temperature>=30:
    day = "Hot"
elif temperature>= 15:
    day = "Warm"
else:
    day = "Cold"
print(f"It's {day} today")
# Out:
# Enter your temperature:   3
# It's Cold today

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
# Write your code here
num = 15
if num % 3 == 0 and num % 5 == 0:
    print("Number is divisible by 3 and 5")
elif num % 3 == 0:
    print("Number is divisible by 3")
elif num % 5 == 0:
    print("Number is divisible by 5")
else:
    print("Number is different")
# Out:
# Number is divisible by 3 and 5

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
# Write your code here
character = input("Enter a character:  ")
if character == "a" or character == "e" or character == "i" or character == "o" or character == "u":
    print("A character is vowel")
else:
    print("A character is not vowel")
# Out:
# Enter a character:   e
# A character is vowel

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
# Write your code here
amount = float(input("Enter total amount:  "))
if amount>=5000:
    discount = amount*.20
elif amount>=2000:
    discount = amount*.10
else:
    discount = 0
net = amount - discount
print(f"""amount = {amount}
discount = {discount}
net amount = {net}""")
# Out:
# Enter total amount:   6000
# amount = 6000.0
# discount = 1200.0
# net amount = 4800.0

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
# Write your code here
age = int(input("Enter your age: "))

if age >= 0 and age <= 12:
    print("Child")
elif age >= 13 and age <= 19:
    print("Teenager")
elif age >= 20 and age <= 59:
    print("Adult")
elif age >= 60:
    print("Senior Citizen")
else:
    print("Invalid age")
# Out:
# Enter your age:  5
# Child

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
# Write your code here
year = int(input("Enter a year:  "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year:   2026
# Not a leap year

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
# Write your code here
day = int(input("Enter week number (1-7): "))

if day == 1:
    print("Monday")
elif day == 2:
    print("Tuesday")
elif day == 3:
    print("Wednesday")
elif day == 4:
    print("Thursday")
elif day == 5:
    print("Friday")
elif day == 6:
    print("Saturday")
elif day == 7:
    print("Sunday")
else:
    print("Invalid number")
# Out:
# Enter week number (1-7):  4
# Thursday

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
# Write your code here
num1 = float(input("Enter first number:  "))
operator = input("Enter operator (+,-,*,/):  ")
num2 = float(input("Enter second number:  "))
if operator == "+":
    result = num1 + num2
    print(result)
elif operator == "-":
    result = num1 - num2
    print(result)
elif operator == "*":
    result = num1 * num2
    print(result)
elif operator == "/":
    result = num1 / num2
    print(result)
else:
    print("Invalid operator")
# Out:
# Enter first number:   2
# Enter operator (+,-,*,/):   *
# Enter second number:   2
# 4.0

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
# Write your code here
weight = float(input("Enter weight in kg: "))
height = float(input("Enter height in meters: "))

bmi = weight / (height ** 2)

print("Your BMI is:", bmi)

if bmi < 18.5:
    print("Category: Underweight")
elif bmi < 25:
    print("Category: Normal")
else:
    print("Category: Overweight")
# Out:
# Enter weight in kg:  67
# Enter height in meters:  1.70688
# Your BMI is: 22.996874933659164
# Category: Normal

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
# Write your code here
correct_pin = 1234
balance = 5000

pin = int(input("Enter your pin:  "))
if pin == correct_pin:
    amount = float(input("Enter withdrawal amount:  "))
    if amount <= balance:
        balance -= amount
        print("Withdrawal Success")
        print(f"Remaining Balance: {balance}")
    else:
        print("Insufficient balance")
else:
    print("Your pin is incorrect")
# Out:
# Enter your pin:   1234
# Enter withdrawal amount:   2000
# Withdrawal Success
# Remaining Balance: 3000.0

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
# Write your code here
correct_username = "Abdullah"
correct_password = 1234
username = input("Enter username:  ")
if username == correct_username:
    password = int(input("Enter your password:  "))
    if password == correct_password:
        print("Login Success")
    else:
        print("Invalid password")
else:
    print("Invalid username")
# Out:
# Enter username:   Abdullah
# Enter your password:   1234
# Login Success

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
# Write your code here
num1 = float(input("Enter your num1:  "))
num2 = float(input("Enter your num2:  "))
num3 = float(input("Enter your num3:  "))
if num1 > num2:
    if num1 > num3:
        print(f"Largest number is: {num1}")
    else:
        print(f"Largest number is: {num3}")
else:
    if num2 > num3:
        print(f"Largest number is: {num2}")
    else:
        print(f"Largest number is: {num3}")
# Out:
# Enter your num1:   23
# Enter your num2:   43
# Enter your num3:   76
# Largest number is: 76.0

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
# Write your code here
age = int(input("Enter your age: "))

if age >= 18:
    id_card = input("Do you have ID? (yes/no): ")

    if id_card == "yes":
        print("Ticket Issued")
    else:
        print("ID required. Ticket not issued")
else:
    print("Not eligible (Age must be 18+)")
# Out:
# Enter your age:  20
# Do you have ID? (yes/no):  yes
# Ticket Issued

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
# Write your code here
marks = int(input("Enter your marks: "))

if marks >= 80:
    interview = input("Interview clear? (yes/no): ")

    if interview == "yes":
        print("Admission Done")
    else:
        print("Interview not clear, Admission rejected")
else:
    print("Marks insufficient, Admission rejected")
# Out:
# Enter your marks:  90
# Interview clear? (yes/no):  yes
# Admission Done

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
# Write your code here
num = float(input("Enter a number: "))

if num > 0:
    if num > 100:
        print("Positive number and greater than 100")
    else:
        print("Positive number and less than or equal to 100")
else:
    print("Number is not positive")
# Out:
# Enter a number:  500
# Positive number and greater than 100

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
# Write your code here
step_1 = input("Veg or Non-Veg: ").strip().lower()

if step_1 == "veg":
    step_2 = input("Paneer or Dal: ").strip().lower()
    if step_2 == "paneer":
        print("Your order Paneer has been confirmed")
    else:
        print("Your order Dal has been confirmed")

elif step_1 == "non-veg":
    step_2 = input("Chicken or Mutton: ").strip().lower()
    if step_2 == "chicken":
        print("Your order Chicken has been confirmed")
    else:
        print("Your order Mutton has been confirmed")

else:
    print("Invalid option")
# Out:
# Veg or Non-Veg:  veg
# Paneer or Dal:  Dal
# Your order Dal has been confirmed

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
# Write your code here
num = int(input("Enter number:  "))
if (num >= -9 and num <= 9):
    print("Sigle digit")
elif (num >= -99 and num <= -10) or (num >= 10 and num <= 99):
    print("Double digit")
elif (num >= -999 and num <= -100) or (num >= 100 and num <= 999):
    print("Triple ditgit")
else:
    print("More than triple digit")
# Out:
# Enter number:   44
# Double digit

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
# Write your code here
salary = float(input("Enter your salary: "))
years = int(input("Enter service years: "))

if years > 5:
    bonus = salary*.05
    final_salary = salary + bonus
    print(f"Bonus added: {bonus}")
    print(f"Final Salary: {final_salary}")
else:
    print(f"No bonus applied. Salary: {salary}")
# Out:
# Enter your salary:  50000
# Enter service years:  6
# Bonus added: 2500.0
# Final Salary: 52500.0

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
# Write your code here
a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

if a == b and b == c:
    print("Equilateral Triangle")
elif a == b or b == c or a == c:
    print("Isosceles Triangle")
else:
    print("Scalene Triangle")
# Out:
# Enter first side:  6
# Enter second side:  4
# Enter third side:  4
# Isosceles Triangle

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
# Write your code here
month = input("Enter month name: ").strip().lower()

if month == "january" or month == "march" or month == "may" or month == "july" or month == "august" or month == "october" or month == "december":
    print("31 days")
elif month == "april" or month == "june" or month == "september" or month == "november":
    print("30 days")
elif month == "february":
    print("28 or 29 days (leap year case)")
else:
    print("Invalid month name")
# Out:
# Enter month name:  april
# 30 days

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
# Write your code here
num = int(input("Enter a number: "))

if num % 2 == 0:
    if num > 50:
        print("Even number and greater than 50")
    else:
        print("Even number and less than or equal to 50")
else:
    print("Number is Odd")
# Out:
# Enter a number:  44
# Even number and less than or equal to 50

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
# Write your code here
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))

if maths >= 40 and science >= 40:
    print("Pass")
else:
    print("Fail")

    if maths < 40:
        print("Maths is weak")
    if science < 40:
        print("Science is weak")
# Out:
# Enter Maths marks:  60
# Enter Science marks:  30
# Fail
# Science is weak

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
# Write your code here
units = int(input("Enter electricity units: "))

bill = 0

if units <= 100:
    bill = 0

elif units <= 200:
    bill = (units - 100) * 5

else:
    bill = (100 * 5) + (units - 200) * 10

print(f"Total Bill: Rs {bill}")
# Out:
# Enter electricity units:  250
# Total Bill: Rs 1000

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
# Write your code here
score = int(input("Enter your score: "))

if score >= 0 and score <= 50:
    print("Beginner Level")

elif score >= 51 and score <= 100:
    print("Intermediate Level")

    boss = input("Did you complete boss level? (yes/no): ").strip().lower()

    if boss == "yes":
        print("Intermediate + Boss Completed")
    else:
        print("Intermediate Level Only")

else:
    print("Invalid or Advanced Score")
# Out:
# Enter your score:  -10
# Intermediate Level

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
# Write your code here
username = input("Enter Username:  ")
password = input("Enter Password:  ")

if username:
    if password:
        print("Credential Entered")
        security = input("Security Question: What is your favorite color?")
        if security:
            print("Access Granted")
        else:
            print("Security question is not answered")
    else:
        print("Missing password")
else:
    print("Missing username")
# Out:
# Enter Username:   Abdullah
# Enter Password:   1234
# Credential Entered
# Security Question: What is your favorite color? blue
# Access Granted
