# %% [markdown]
# # 🔹 Q1 Aik variable a banao jisme value 20 ho, aur aik variable b banao jisme value 5 ho. In dono ko divide karo aur result print karo.

# %%
# type your code here

# %%
num1 = 20
num2 = 5
result = num1 / num2
print(result)
# Out:
# 4.0

# %%
print(num1/num2)
# Out:
# 4.0

# %% [markdown]
# # 🔹 Q2 Aik variable name banao jisme apna naam likho. Usay print karo aur uska lower case bhi print karo.

# %%
# type your code here

# %%
name = "Hassan"
print(name.lower())
# Out:
# hassan

# %%
print(name.upper())
# Out:
# HASSAN

# %% [markdown]
# # 🔹 Q3 Aik string likho: "hello world from python" Isay aise print karo ke har word ka pehla letter capital ho.

# %%
# type your code here

# %%
peragraph = "hello world from python"
print(peragraph.title())
# Out:
# Hello World From Python

# %% [markdown]
# # 🔹 Q4 Aik variable x = 10 aur y = 3 banao. Inka modulus (%) nikaal kar print karo.

# %%
# type your code here

# %%
x = 10
y = 3
modulus = x % y
print(modulus)
# Out:
# 1

# %% [markdown]
# # 🔹 Q5 Aik variable text = "PYTHON" banao. Isay lower case mai convert karke print karo

# %%
# type your code here

# %%
text = "PYTHON"
text_lower = text.lower()
print(text_lower)
# Out:
# python

# %% [markdown]
# # 🔹 Q6 Aik string "data science" likho. Iski length nikaal kar print karo

# %%
# type your code here

# %%
text = "data science"
text_length = len(text)
print(text_length)
# Out:
# 12

# %% [markdown]
# # 🔹 Q7 Aik variable num = 7 banao. Iska square (power) nikaal kar print karo.

# %%
# type your code here

# %%
num = 7
num_power = 7**2
print(num_power)
# Out:
# 49

# %% [markdown]
# # 🔹 Q8 Aik string "hello" likho. Isay 3 dafa repeat karke print karo.

# %%
# type your code here

# %%
text = "hello"
text_repeat = text*3
print(text_repeat)
# Out:
# hellohellohello

# %% [markdown]
# # 🔹 Q9 Aik variable a = 15 aur b = 10 banao. Check karo ke a bara hai b se ya nahi aur result print karo

# %%
# type your code here

# %%
a = 15
b = 10
result = a == b
print(result)
# Out:
# False

# %% [markdown]
# # 🔹 Q10 Aik string "i love python programming" likho. Isay aise print karo ke pehla letter capital ho (sirf first letter).

# %%
# type your code here

# %%
text = "i love python programming"
print(text.capitalize())
# Out:
# I love python programming

# %% [markdown]
# # 🔹 Q11 (Addition Input) User se 2 numbers lo aur unka sum print karo using f-string.

# %%
# type your code here

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
sum = num1 + num2
print(f"Sum is: {sum}")
# Out:
# Enter first number:  3
# Enter second number:  5
# Sum is: 8

# %% [markdown]
# # 🔹 Q12 (Full Name + Upper/Lower)  User se first name aur last name lo aur:  1)  full name print karo  2) upper case 3)lower case

# %%
# type your code here

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
full_name = first_name + " " + last_name
print(full_name)
print(full_name.upper())
print(full_name.lower())
# Out:
# Enter your first name Abdullah
# Enter your last name Tanweer
# Abdullah Tanweer
# ABDULLAH TANWEER
# abdullah tanweer

# %% [markdown]
# # 🔹 Q13 (Sentence Formatting) User se aik sentence lo aur usay: 1) title case 2)capitalize  3)length print karo

# %%
# type your code here

# %%
sentence = input("Message: ")
print(sentence.title())
print(sentence.capitalize())
print(len(sentence))
# Out:
# Message Hello my name is Abdullah
# Hello My Name Is Abdullah
# Hello my name is abdullah
# 25

# %% [markdown]
# # 🔹 Q14 (Marks + Total) User se 3 subjects ke marks lo aur total print karo using f-string.

# %%
# type your code here

# %%
marks_1 = float(input("Enter your Math Marks: "))
marks_2 = float(input("Enter your Physics Marks: "))
marks_3 = float(input("Enter your English Marks: "))
sum = marks_1 + marks_2 + marks_3
print(f"Total marks {sum}")
# Out:
# Enter your Math Marks 10.3
# Enter your Physics Marks 48.4
# Enter your English Marks 34
# Total marks 92.7

# %% [markdown]
# # 🔹 Q15 (Simple Bank Info / ID Card Style ) User se: 1) name  2)CNIC  3)balance lo aur formatted output dikhao

# %%
name = input("Enter your Full Name: ")
cnic = input("Enter your CNIC: ")
balance = float(input("Enter your Bank Balance: "))
print(f"Name: {name}")
print(f"CNIC: {cnic}")
print(f"Current Balance: {balance}")
